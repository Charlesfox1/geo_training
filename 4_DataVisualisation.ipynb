# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv("data-sample.csv")

# %%
df
# Out:
#         Unnamed: 0 frequency period_ending ship_type ship_size  \
# 0                0   MONTHLY    2018-01-31    BULKER    MEDIUM
# 1                1   MONTHLY    2018-01-31    BULKER     SMALL
# 2                2   MONTHLY    2018-01-31    BULKER    MEDIUM
# 3                3   MONTHLY    2018-01-31    BULKER     SMALL
# 4                4   MONTHLY    2018-01-31    BULKER     SMALL
# ...            ...       ...           ...       ...       ...
# 228768      228768   MONTHLY    2018-12-31    TANKER     SMALL
# 228769      228769   MONTHLY    2018-12-31    TANKER    MEDIUM
# 228770      228770   MONTHLY    2018-12-31    TANKER     SMALL
# 228771      228771   MONTHLY    2018-12-31    TANKER     SMALL
# 228772      228772   MONTHLY    2018-12-31    TANKER     SMALL
#
#                                      port_name   port_country region_corridor  \
# 0                                       Durban   South Africa          Africa
# ...
